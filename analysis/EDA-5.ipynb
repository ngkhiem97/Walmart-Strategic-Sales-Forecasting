# %%
import pandas as pd
import numpy as np

ca1 = pd.read_csv('../data/processed/CA_1_sales_data.csv')
ca2 = pd.read_csv('../data/processed/CA_2_sales_data.csv')
ca3 = pd.read_csv('../data/processed/CA_3_sales_data.csv')
ca4 = pd.read_csv('../data/processed/CA_4_sales_data.csv')

tx1 = pd.read_csv('../data/processed/TX_1_sales_data.csv')
tx2 = pd.read_csv('../data/processed/TX_2_sales_data.csv')
tx3 = pd.read_csv('../data/processed/TX_3_sales_data.csv')

wi1 = pd.read_csv('../data/processed/WI_1_sales_data.csv')
wi2 = pd.read_csv('../data/processed/WI_2_sales_data.csv')
wi3 = pd.read_csv('../data/processed/WI_3_sales_data.csv')

ca1.loc[ca1["event_name_1"] == "None", "event_name_1"] = np.NaN
ca1.loc[ca1["event_type_1"] == "None", "event_type_1"] = np.NaN
ca1.loc[ca1["event_name_2"] == "None", "event_name_2"] = np.NaN
ca1.loc[ca1["event_type_2"] == "None", "event_type_2"] = np.NaN

ca2.loc[ca2["event_name_1"] == "None", "event_name_1"] = np.NaN
ca2.loc[ca2["event_type_1"] == "None", "event_type_1"] = np.NaN
ca2.loc[ca2["event_name_2"] == "None", "event_name_2"] = np.NaN
ca2.loc[ca2["event_type_2"] == "None", "event_type_2"] = np.NaN

ca3.loc[ca3["event_name_1"] == "None", "event_name_1"] = np.NaN
ca3.loc[ca3["event_type_1"] == "None", "event_type_1"] = np.NaN
ca3.loc[ca3["event_name_2"] == "None", "event_name_2"] = np.NaN
ca3.loc[ca3["event_type_2"] == "None", "event_type_2"] = np.NaN


ca4.loc[ca4["event_name_1"] == "None", "event_name_1"] = np.NaN
ca4.loc[ca4["event_type_1"] == "None", "event_type_1"] = np.NaN
ca4.loc[ca4["event_name_2"] == "None", "event_name_2"] = np.NaN
ca4.loc[ca4["event_type_2"] == "None", "event_type_2"] = np.NaN

tx1.loc[tx1["event_name_1"] == "None", "event_name_1"] = np.NaN
tx1.loc[tx1["event_type_1"] == "None", "event_type_1"] = np.NaN
tx1.loc[tx1["event_name_2"] == "None", "event_name_2"] = np.NaN
tx1.loc[tx1["event_type_2"] == "None", "event_type_2"] = np.NaN

tx2.loc[tx2["event_name_1"] == "None", "event_name_1"] = np.NaN
tx2.loc[tx2["event_type_1"] == "None", "event_type_1"] = np.NaN
tx2.loc[tx2["event_name_2"] == "None", "event_name_2"] = np.NaN
tx2.loc[tx2["event_type_2"] == "None", "event_type_2"] = np.NaN

tx3.loc[tx3["event_name_1"] == "None", "event_name_1"] = np.NaN
tx3.loc[tx3["event_type_1"] == "None", "event_type_1"] = np.NaN
tx3.loc[tx3["event_name_2"] == "None", "event_name_2"] = np.NaN
tx3.loc[tx3["event_type_2"] == "None", "event_type_2"] = np.NaN

wi1.loc[wi1["event_name_1"] == "None", "event_name_1"] = np.NaN
wi1.loc[wi1["event_type_1"] == "None", "event_type_1"] = np.NaN
wi1.loc[wi1["event_name_2"] == "None", "event_name_2"] = np.NaN
wi1.loc[wi1["event_type_2"] == "None", "event_type_2"] = np.NaN

wi2.loc[wi2["event_name_1"] == "None", "event_name_1"] = np.NaN
wi2.loc[wi2["event_type_1"] == "None", "event_type_1"] = np.NaN
wi2.loc[wi2["event_name_2"] == "None", "event_name_2"] = np.NaN
wi2.loc[wi2["event_type_2"] == "None", "event_type_2"] = np.NaN

wi3.loc[wi3["event_name_1"] == "None", "event_name_1"] = np.NaN
wi3.loc[wi3["event_type_1"] == "None", "event_type_1"] = np.NaN
wi3.loc[wi3["event_name_2"] == "None", "event_name_2"] = np.NaN
wi3.loc[wi3["event_type_2"] == "None", "event_type_2"] = np.NaN

# %%
ca1.head()
# Out:
#    Unnamed: 0  wm_yr_wk  wday  month  year event_name_1 event_type_1  \
# 0  2011-01-29     11101     1      1  2011          NaN          NaN
# 1  2011-01-30     11101     2      1  2011          NaN          NaN
# 2  2011-01-31     11101     3      1  2011          NaN          NaN
# 3  2011-02-01     11101     4      2  2011          NaN          NaN
# 4  2011-02-02     11101     5      2  2011          NaN          NaN
#
#   event_name_2 event_type_2      cpi  ...  gas_price  snap_ca  ca_walmart  \
# 0          NaN          NaN  221.187  ...      3.163        0       39.50
# 1          NaN          NaN  221.187  ...      3.163        0       42.50
# 2          NaN          NaN  221.187  ...      3.155        0       36.50
# 3          NaN          NaN  221.898  ...      3.155        1       42.40
# 4          NaN          NaN  221.898  ...      3.155        1       38.69
#
#    ca_hobbies  ca_household  ca_foods  store_sales  median_price  min_price  \
# ...

# %%
print("----- CA_1 sales data -----")
ca1.isnull().sum()
# Out:
# ----- CA_1 sales data -----
# Unnamed: 0              0
# wm_yr_wk                0
# wday                    0
# month                   0
# year                    0
# event_name_1         1792
# event_type_1         1792
# event_name_2         1947
# event_type_2         1947
# cpi                     0
# unemployment_rate       0
# gas_price               0
# snap_ca                 0
# ca_walmart              0
# ca_hobbies              0
# ca_household            0
# ca_foods                0
# store_sales            10
# median_price            0
# min_price               0
# max_price               0
# dtype: int64

# %%
print("----- CA_2 sales data -----")
ca2.isnull().sum()
# Out:
# ----- CA_2 sales data -----
# Unnamed: 0              0
# wm_yr_wk                0
# wday                    0
# month                   0
# year                    0
# event_name_1         1792
# event_type_1         1792
# event_name_2         1947
# event_type_2         1947
# cpi                     0
# unemployment_rate       0
# gas_price               0
# snap_ca                 0
# ca_walmart              0
# ca_hobbies              0
# ca_household            0
# ca_foods                0
# store_sales            10
# median_price            0
# min_price               0
# max_price               0
# dtype: int64

# %%
print("----- CA_3 sales data -----")
ca3.isnull().sum()
# Out:
# ----- CA_3 sales data -----
# Unnamed: 0              0
# wm_yr_wk                0
# wday                    0
# month                   0
# year                    0
# event_name_1         1792
# event_type_1         1792
# event_name_2         1947
# event_type_2         1947
# cpi                     0
# unemployment_rate       0
# gas_price               0
# snap_ca                 0
# ca_walmart              0
# ca_hobbies              0
# ca_household            0
# ca_foods                0
# store_sales            10
# median_price            0
# min_price               0
# max_price               0
# dtype: int64

# %%
print("----- CA_4 sales data -----")
ca4.isnull().sum()
# Out:
# ----- CA_4 sales data -----
# Unnamed: 0              0
# wm_yr_wk                0
# wday                    0
# month                   0
# year                    0
# event_name_1         1792
# event_type_1         1792
# event_name_2         1947
# event_type_2         1947
# cpi                     0
# unemployment_rate       0
# gas_price               0
# snap_ca                 0
# ca_walmart              0
# ca_hobbies              0
# ca_household            0
# ca_foods                0
# store_sales            10
# median_price            0
# min_price               0
# max_price               0
# dtype: int64

# %%
print("----- TX_1 sales data -----")
tx1.isnull().sum()
# Out:
# ----- TX_1 sales data -----
# Unnamed: 0              0
# wm_yr_wk                0
# wday                    0
# month                   0
# year                    0
# event_name_1         1792
# event_type_1         1792
# event_name_2         1947
# event_type_2         1947
# cpi                     0
# unemployment_rate       0
# gas_price               0
# snap_tx                 0
# tx_walmart              0
# tx_hobbies              0
# tx_household            0
# tx_foods                0
# store_sales            10
# median_price            0
# min_price               0
# max_price               0
# dtype: int64

# %%
print("----- TX_2 sales data -----")
tx2.isnull().sum()
# Out:
# ----- TX_2 sales data -----
# Unnamed: 0              0
# wm_yr_wk                0
# wday                    0
# month                   0
# year                    0
# event_name_1         1792
# event_type_1         1792
# event_name_2         1947
# event_type_2         1947
# cpi                     0
# unemployment_rate       0
# gas_price               0
# snap_tx                 0
# tx_walmart              0
# tx_hobbies              0
# tx_household            0
# tx_foods                0
# store_sales            10
# median_price            0
# min_price               0
# max_price               0
# dtype: int64

# %%
print("----- TX_3 sales data -----")
tx3.isnull().sum()
# Out:
# ----- TX_3 sales data -----
# Unnamed: 0              0
# wm_yr_wk                0
# wday                    0
# month                   0
# year                    0
# event_name_1         1792
# event_type_1         1792
# event_name_2         1947
# event_type_2         1947
# cpi                     0
# unemployment_rate       0
# gas_price               0
# snap_tx                 0
# tx_walmart              0
# tx_hobbies              0
# tx_household            0
# tx_foods                0
# store_sales            10
# median_price            0
# min_price               0
# max_price               0
# dtype: int64

# %%
print("----- WI_1 sales data -----")
wi1.isnull().sum()
# Out:
# ----- WI_1 sales data -----
# Unnamed: 0              0
# wm_yr_wk                0
# wday                    0
# month                   0
# year                    0
# event_name_1         1792
# event_type_1         1792
# event_name_2         1947
# event_type_2         1947
# cpi                     0
# unemployment_rate       0
# gas_price               0
# snap_wi                 0
# wi_walmart              0
# wi_hobbies              0
# wi_household            0
# wi_foods                0
# store_sales            10
# median_price            0
# min_price               0
# max_price               0
# dtype: int64

# %%
print("----- WI_2 sales data -----")
wi2.isnull().sum()
# Out:
# ----- WI_2 sales data -----
# Unnamed: 0              0
# wm_yr_wk                0
# wday                    0
# month                   0
# year                    0
# event_name_1         1792
# event_type_1         1792
# event_name_2         1947
# event_type_2         1947
# cpi                     0
# unemployment_rate       0
# gas_price               0
# snap_wi                 0
# wi_walmart              0
# wi_hobbies              0
# wi_household            0
# wi_foods                0
# store_sales            10
# median_price            0
# min_price               0
# max_price               0
# dtype: int64

# %%
print("----- WI_3 sales data -----")
wi3.isnull().sum()
# Out:
# ----- WI_3 sales data -----
# Unnamed: 0              0
# wm_yr_wk                0
# wday                    0
# month                   0
# year                    0
# event_name_1         1792
# event_type_1         1792
# event_name_2         1947
# event_type_2         1947
# cpi                     0
# unemployment_rate       0
# gas_price               0
# snap_wi                 0
# wi_walmart              0
# wi_hobbies              0
# wi_household            0
# wi_foods                0
# store_sales            10
# median_price            0
# min_price               0
# max_price               0
# dtype: int64

# %%
print("CA_1 rows with NaN values in store_sales column")
ca1[ca1.isna().any(axis=1)]
# Out:
# CA_1 rows with NaN values in store_sales column
#       Unnamed: 0  wm_yr_wk  wday  month  year event_name_1 event_type_1  \
# 0     2011-01-29     11101     1      1  2011          NaN          NaN
# 1     2011-01-30     11101     2      1  2011          NaN          NaN
# 2     2011-01-31     11101     3      1  2011          NaN          NaN
# 3     2011-02-01     11101     4      2  2011          NaN          NaN
# 4     2011-02-02     11101     5      2  2011          NaN          NaN
# ...          ...       ...   ...    ...   ...          ...          ...
# 1946  2016-05-28     11618     1      5  2016          NaN          NaN
# 1947  2016-05-29     11618     2      5  2016          NaN          NaN
# 1948  2016-05-30     11618     3      5  2016  MemorialDay     National
# 1949  2016-05-31     11618     4      5  2016          NaN          NaN
# 1950  2016-06-01     11618     5      6  2016          NaN          NaN
#
# ...

# %%
print("TX_1 rows with NaN values in store_sales column")
tx1[tx1.isna().any(axis=1)]
# Out:
# TX_1 rows with NaN values in store_sales column
#       Unnamed: 0  wm_yr_wk  wday  month  year event_name_1 event_type_1  \
# 0     2011-01-29     11101     1      1  2011          NaN          NaN
# 1     2011-01-30     11101     2      1  2011          NaN          NaN
# 2     2011-01-31     11101     3      1  2011          NaN          NaN
# 3     2011-02-01     11101     4      2  2011          NaN          NaN
# 4     2011-02-02     11101     5      2  2011          NaN          NaN
# ...          ...       ...   ...    ...   ...          ...          ...
# 1946  2016-05-28     11618     1      5  2016          NaN          NaN
# 1947  2016-05-29     11618     2      5  2016          NaN          NaN
# 1948  2016-05-30     11618     3      5  2016  MemorialDay     National
# 1949  2016-05-31     11618     4      5  2016          NaN          NaN
# 1950  2016-06-01     11618     5      6  2016          NaN          NaN
#
# ...
