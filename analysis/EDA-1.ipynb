# %%
import pandas as pd

# %% [markdown]
# # Dataset: Fuel Price

# %%
fuel_data = pd.read_csv('../data/raw/PET_PRI_GND_DCUS_NUS_W.csv')
fuel_data["Date"] = pd.to_datetime(fuel_data["Date"])
fuel_data = fuel_data.set_index("Date")
fuel_data.head()
# Out:
#                A1     A2     A3     R1     R2     R3     M1     M2     M3  \
# Date
# 1995-01-02  1.127  1.104  1.231  1.079  1.063  1.167  1.170  1.159  1.298
# 1995-01-09  1.134  1.111  1.232  1.086  1.070  1.169  1.177  1.164  1.300
# 1995-01-16  1.126  1.102  1.231  1.078  1.062  1.169  1.168  1.155  1.299
# 1995-01-23  1.132  1.110  1.226  1.083  1.068  1.165  1.177  1.165  1.296
# 1995-01-30  1.131  1.109  1.221  1.083  1.068  1.162  1.176  1.163  1.291
#
#                P1     P2     P3     D1
# Date
# 1995-01-02  1.272  1.250  1.386  1.104
# 1995-01-09  1.279  1.256  1.387  1.102
# 1995-01-16  1.271  1.249  1.385  1.100
# 1995-01-23  1.277  1.256  1.378  1.095
# 1995-01-30  1.275  1.255  1.370  1.090

# %%
fuel_data[fuel_data.columns].plot(figsize=(20, 10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
fuel_data["A1"].plot(figsize=(20, 10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# fuel_data['month'] = fuel_data.index.month
# fuel_data['year'] = fuel_data.index.year
# fuel_data.groupby(['year','month'],as_index=False).mean()["A1"].plot(figsize=(20, 10))

# %%
from matplotlib import pyplot

fuel_data.hist(figsize=(20,10))
pyplot.show()
